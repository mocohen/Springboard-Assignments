# %%
import pandas as pd

# %% [markdown]
# ## imports for Python, Pandas

# %%
import json
from pandas.io.json import json_normalize

# %% [markdown]
# ****
# ## JSON exercise
#
# Using data in file 'data/world_bank_projects.json' and the techniques demonstrated above,
# 1. Find the 10 countries with most projects
# 2. Find the top 10 major project themes (using column 'mjtheme_namecode')
# 3. In 2. above you will notice that some entries have only the code and the name is missing. Create a dataframe with the missing names filled in.

# %%
# First, read the data into a pandas data frame
json_df = pd.read_json('data/world_bank_projects.json')
#json_df.info()

# %% [markdown]
# # Find the 10 countries with most projects
# Pandas has built in function (*value_counts*) to count number of occurances of a value in a column.
# Here, simply count the times a country name appears

# %%
# Pandas has built in function (value_counts) to count number of occurances of 
json_df.countryshortname.value_counts()[:10]
# Out:
# Indonesia             19
# China                 19
# Vietnam               17
# India                 16
# Yemen, Republic of    13
# Nepal                 12
# Morocco               12
# Bangladesh            12
# Mozambique            11
# Africa                11
# Name: countryshortname, dtype: int64

# %% [markdown]
# # Find the top 10 major project themes (using column 'mjtheme_namecode')
# The __mjtheme_namecode__ codes and corresponding descriptions are contained in a list if we simply use the read_json function above. Instead, I first load the json file, and then use json_normalize to expand into one row for each code for each project.

# %%
data = json.load(open('data/world_bank_projects.json'))
# Use the json_normalize as above. More columns can be read in if needed
expanded_data = json_normalize(data, 'mjtheme_namecode', ['_id','countryshortname', 'project_name'])
#expanded_data.info()

# %% [markdown]
# Then, as above, we can use value_counts to find the most common project themes

# %%
expanded_data.code.value_counts()[:10]
# Out:
# 11    250
# 10    216
# 8     210
# 2     199
# 6     168
# 4     146
# 7     130
# 5      77
# 9      50
# 1      38
# Name: code, dtype: int64

# %% [markdown]
# # In 2. above you will notice that some entries have only the code and the name is missing. Create a dataframe with the missing names filled in.
# To first find the name for each code, I group by code, and then take the max of the names. Here, max() works, since having a description will be 'greater than' an empty string

# %%
code_names = expanded_data[['code', 'name']].groupby('code').max()
#code_names

# %% [markdown]
# Now that I have a dataframe with each code and codename, I can merge this (outer join) with the original data frame that has the missing data.

# %%
filled_missing = pd.merge(expanded_data, code_names, how='outer', left_on='code', right_index=True) 
# Create new column that is the max of the two description strings
filled_missing['name'] = filled_missing[['name_x','name_y']].apply(max, axis=1)
filled_missing = filled_missing.drop(columns=['name_x','name_y'])

# %%
filled_missing
#filled_missing.info()
# Out:
#      code                                   _id  \
# 0       8  {'$oid': '52b213b38594d8a2be17c780'}
# 17      8  {'$oid': '52b213b38594d8a2be17c787'}
# 41      8  {'$oid': '52b213b38594d8a2be17c791'}
# 43      8  {'$oid': '52b213b38594d8a2be17c792'}
# 44      8  {'$oid': '52b213b38594d8a2be17c792'}
# 47      8  {'$oid': '52b213b38594d8a2be17c792'}
# 57      8  {'$oid': '52b213b38594d8a2be17c797'}
# 58      8  {'$oid': '52b213b38594d8a2be17c797'}
# 69      8  {'$oid': '52b213b38594d8a2be17c79a'}
# 79      8  {'$oid': '52b213b38594d8a2be17c79e'}
# 91      8  {'$oid': '52b213b38594d8a2be17c7a2'}
# 113     8  {'$oid': '52b213b38594d8a2be17c7a9'}
# 117     8  {'$oid': '52b213b38594d8a2be17c7ab'}
# 120     8  {'$oid': '52b213b38594d8a2be17c7ad'}
# 146     8  {'$oid': '52b213b38594d8a2be17c7b6'}
# 147     8  {'$oid': '52b213b38594d8a2be17c7b6'}
# 148     8  {'$oid': '52b213b38594d8a2be17c7b6'}
# 186     8  {'$oid': '52b213b38594d8a2be17c7c4'}
# 190     8  {'$oid': '52b213b38594d8a2be17c7c6'}
# 191     8  {'$oid': '52b213b38594d8a2be17c7c6'}
# 192     8  {'$oid': '52b213b38594d8a2be17c7c6'}
# 206     8  {'$oid': '52b213b38594d8a2be17c7cb'}
# 228     8  {'$oid': '52b213b38594d8a2be17c7d4'}
# 229     8  {'$oid': '52b213b38594d8a2be17c7d5'}
# 237     8  {'$oid': '52b213b38594d8a2be17c7d9'}
# 238     8  {'$oid': '52b213b38594d8a2be17c7d9'}
# 239     8  {'$oid': '52b213b38594d8a2be17c7da'}
# 240     8  {'$oid': '52b213b38594d8a2be17c7da'}
# 245     8  {'$oid': '52b213b38594d8a2be17c7dd'}
# 278     8  {'$oid': '52b213b38594d8a2be17c7e8'}
# ...   ...                                   ...
# 1102    9  {'$oid': '52b213b38594d8a2be17c8f4'}
# 1103    9  {'$oid': '52b213b38594d8a2be17c8f4'}
# 1104    9  {'$oid': '52b213b38594d8a2be17c8f4'}
# 1166    9  {'$oid': '52b213b38594d8a2be17c905'}
# 1290    9  {'$oid': '52b213b38594d8a2be17c930'}
# 1303    9  {'$oid': '52b213b38594d8a2be17c933'}
# 1318    9  {'$oid': '52b213b38594d8a2be17c938'}
# 1342    9  {'$oid': '52b213b38594d8a2be17c941'}
# 1347    9  {'$oid': '52b213b38594d8a2be17c942'}
# 1425    9  {'$oid': '52b213b38594d8a2be17c95a'}
# 1426    9  {'$oid': '52b213b38594d8a2be17c95a'}
# 1428    9  {'$oid': '52b213b38594d8a2be17c95b'}
# 1470    9  {'$oid': '52b213b38594d8a2be17c969'}
# 1473    9  {'$oid': '52b213b38594d8a2be17c969'}
# 1495    9  {'$oid': '52b213b38594d8a2be17c973'}
# 252     3  {'$oid': '52b213b38594d8a2be17c7df'}
# 359     3  {'$oid': '52b213b38594d8a2be17c801'}
# 415     3  {'$oid': '52b213b38594d8a2be17c813'}
# 493     3  {'$oid': '52b213b38594d8a2be17c82c'}
# 508     3  {'$oid': '52b213b38594d8a2be17c830'}
# 509     3  {'$oid': '52b213b38594d8a2be17c830'}
# 691     3  {'$oid': '52b213b38594d8a2be17c86d'}
# 789     3  {'$oid': '52b213b38594d8a2be17c88a'}
# 1029    3  {'$oid': '52b213b38594d8a2be17c8dc'}
# 1209    3  {'$oid': '52b213b38594d8a2be17c912'}
# 1287    3  {'$oid': '52b213b38594d8a2be17c92e'}
# 1302    3  {'$oid': '52b213b38594d8a2be17c933'}
# 1316    3  {'$oid': '52b213b38594d8a2be17c937'}
# 1411    3  {'$oid': '52b213b38594d8a2be17c953'}
# 1434    3  {'$oid': '52b213b38594d8a2be17c95e'}
#
#                       countryshortname  \
# 0                             Ethiopia
# 17                               China
# 41                          Madagascar
# 43                            Cambodia
# 44                            Cambodia
# 47                            Cambodia
# 57                          Tajikistan
# 58                          Tajikistan
# 69    Lao People's Democratic Republic
# 79                              Angola
# 91                          Bangladesh
# 113                 Congo, Republic of
# 117              Sao Tome and Principe
# 120                             Africa
# 146                       Sierra Leone
# 147                       Sierra Leone
# 148                       Sierra Leone
# 186                            Lebanon
# 190                         Tajikistan
# 191                         Tajikistan
# 192                         Tajikistan
# 206                    Kyrgyz Republic
# 228                         Mozambique
# 229                         Tajikistan
# 237                           Zimbabwe
# 238                           Zimbabwe
# 239                               Mali
# 240                               Mali
# 245                        Afghanistan
# 278                            Georgia
# ...                                ...
# 1102                          Colombia
# 1103                          Colombia
# 1104                          Colombia
# 1166                West Bank and Gaza
# 1290                          Tanzania
# 1303                           Bolivia
# 1318                             Nepal
# 1342                            Africa
# 1347                        Bangladesh
# 1425                          Pakistan
# 1426                          Pakistan
# 1428                         Indonesia
# 1470                  Papua New Guinea
# 1473                  Papua New Guinea
# 1495                             Kenya
# 252                             Guinea
# 359                             Poland
# 415                             Turkey
# 493                              Sudan
# 508                          Indonesia
# 509                          Indonesia
# 691                            Burundi
# 789                          Nicaragua
# 1029                           Albania
# 1209                             Kenya
# 1287            Bosnia and Herzegovina
# 1302                           Bolivia
